# %%
import requests
from bs4 import BeautifulSoup

def extract_links(url):
    try:
        # Check if the URL has a scheme, if not, prepend 'http://'
        if not url.startswith(('http://', 'https://')):
            url = 'http://' + url

        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses

        soup = BeautifulSoup(response.text, 'html.parser')
        links = [a['href'] for a in soup.find_all('a', href=True)]
        return links
    except requests.exceptions.RequestException as e:
        print(f"Error fetching links from {url}: {e}")
        return []

def main():
    # Replace 'your_excel_file.xlsx' with the actual path to your Excel file
    excel_file_path = 'Input.xlsx'

    # Read the Excel file into a pandas DataFrame
    df = pd.read_excel(excel_file_path)

    # Assuming your Excel file has a column named 'website_url' containing the URLs
    for index, row in df.iterrows():
        website_url = row['URL']

        # Extract links from the website
        links = extract_links(website_url)

        # Print or save the links as needed
        print(f"Links from {website_url}:")
        for link in links:
            print(link)

        print("\n")

if __name__ == "__main__":
    main()
# Out:
# Links from https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/:
# https://insights.blackcoffer.com/category/our-success-stories/
# https://insights.blackcoffer.com/category/our-success-stories/banking-securities-and-insurance/
# https://insights.blackcoffer.com/category/our-success-stories/energy-our-success-stories/
# https://insights.blackcoffer.com/category/our-success-stories/entertainment-our-success-stories/
# https://insights.blackcoffer.com/category/our-success-stories/fast-moving-consumer-goods/
# https://insights.blackcoffer.com/category/our-success-stories/government-think-tanks/
# https://insights.blackcoffer.com/category/our-success-stories/healthcare-our-success-stories/
# https://insights.blackcoffer.com/category/our-success-stories/infrastructure-real-estate/
# https://insights.blackcoffer.com/category/our-success-stories/it/
# ...

# %%
import requests
from bs4 import BeautifulSoup

def extract_article(link):
    try:
        # Send a GET request to the provided link
        response = requests.get(link)
        response.raise_for_status()  # Raise an exception for bad requests

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the article title
        title = soup.title.text.strip()

        # Extract the article text
        article_text = ""
        paragraphs = soup.find_all('p')  # Adjust the tag based on the structure of the webpage
        for paragraph in paragraphs:
            article_text += paragraph.text + "\n"

        return title, article_text

    except Exception as e:
        print(f"Error: {e}")
        return None, None

# Example usage
link = "https://insights.blackcoffer.com/category/our-success-stories/"  # Remove the extra single quote
title, text = extract_article(link)

if title and text:
    print(f"Title: {title}")
    print("\nArticle Text:")
    print(text)
else:
    print("Failed to extract article information.")
# Out:
# Title: Our Success Stories Archives - Blackcoffer Insights
#
# Article Text:
# Grafana Dashboard to visualize and analyze sensors’ data
# MVP for a software that analyses content from audio (Pharma-based)
# Data Engineering and Management tool (Airbyte) with custom data connectors to manage CRM database
# Text Summarizing Tool to scrape and summarize pubmed medical papers
# Methodology for ETL Discovery Tool using LLMA, OpenAI, Langchain
# Methodology for database discovery tool using openai, LLMA, Langchain
# Chatbot using VoiceFlow
# How To Secure (SSL) Nginx with Let’s Encrypt on Ubuntu (Cloud VM, GCP, AWS, Azure, Linode) and Add Domain
# Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.
# Rising IT Cities and Their Impact on the Economy, Environment, Infrastructure, and City Life in Future
# Internet Demand’s Evolution, Communication Impact, and 2035’s Alternative Pathways
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

def extract_links(url):
    try:
        # Check if the URL has a scheme, if not, prepend 'http://'
        if not url.startswith(('http://', 'https://')):
            url = 'http://' + url

        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses

        soup = BeautifulSoup(response.text, 'html.parser')
        links = [a['href'] for a in soup.find_all('a', href=True)]
        return links
    except requests.exceptions.RequestException as e:
        print(f"Error fetching links from {url}: {e}")
        return []

def extract_article(link):
    try:
        # Send a GET request to the provided link
        response = requests.get(link)
        response.raise_for_status()  # Raise an exception for bad requests

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the article title
        title = soup.title.text.strip()

        # Extract the article text
        article_text = ""
        paragraphs = soup.find_all('p')  # Adjust the tag based on the structure of the webpage
        for paragraph in paragraphs:
            article_text += paragraph.text + "\n"

        return title, article_text

    except Exception as e:
        print(f"Error extracting article from {link}: {e}")
        return None, None

def scrape_and_store_data(excel_file_path):
    # Read the Excel file into a pandas DataFrame
    df = pd.read_excel(excel_file_path)

    # Assuming your Excel file has a column named 'website_url' containing the URLs
    for index, row in df.iterrows():
        website_url = row['URL']
        url_id = row['URL_ID']

        # Extract links from the website
        links = extract_links(website_url)

        print(f"Processing {len(links)} links for URL_ID {url_id}")

        for link in links:
            # Create a text file for each article with URL_ID as the name
            title, text = extract_article(link)
            if title and text:
                # Use os.path.join for a more platform-independent way of joining path components
                file_name = os.path.join(f"{url_id}_{link.replace('/', '_').replace(':', '_')}.txt")
                with open(file_name, 'w', encoding='utf-8') as file:
                    file.write(f"Title: {title}\n\nArticle Text:\n{text}\n\n")
                print(f"Saved {file_name}")
            else:
                print(f"Failed to extract article information from {link}.")

if __name__ == "__main__":
    excel_file_path = 'Input.xlsx'
    scrape_and_store_data(excel_file_path)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extract_links(url):
    try:
        # Check if the URL has a scheme, if not, prepend 'http://'
        if not url.startswith(('http://', 'https://')):
            url = 'http://' + url

        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses

        soup = BeautifulSoup(response.text, 'html.parser')
        links = [a['href'] for a in soup.find_all('a', href=True)]
        return links
    except requests.exceptions.RequestException as e:
        print(f"Error fetching links from {url}: {e}")
        return []

def extract_article(link):
    try:
        # Send a GET request to the provided link
        response = requests.get(link)
        response.raise_for_status()  # Raise an exception for bad requests

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the article title
        title = soup.title.text.strip()

        # Extract the article text
        article_text = ""
        paragraphs = soup.find_all('p')  # Adjust the tag based on the structure of the webpage
        for paragraph in paragraphs:
            article_text += paragraph.text + "\n"

        return title, article_text

    except Exception as e:
        print(f"Error: {e}")
        return None, None

def scrape_and_store_data(excel_file_path):
    # Read the Excel file into a pandas DataFrame
    df = pd.read_excel(excel_file_path)

    # Assuming your Excel file has a column named 'website_url' containing the URLs
    for index, row in df.iterrows():
        website_url = row['URL']
        url_id = row['URL_ID']

        # Extract links from the website
        links = extract_links(website_url)

        # Create a text file for each URL_ID
        with open(f"{url_id}.txt", 'w', encoding='utf-8') as file:
            # Write the article title and text to the text file
            for link in links:
                title, text = extract_article(link)
                if title and text:
                    file.write(f"Title: {title}\n")
                    file.write("\nArticle Text:\n")
                    file.write(text + "\n\n")
                else:
                    file.write(f"Failed to extract article information from {link}.\n")

if __name__ == "__main__":
    excel_file_path = 'Input.xlsx'
    scrape_and_store_data(excel_file_path)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extract_links(url):
    try:
        # Check if the URL has a scheme, if not, prepend 'http://'
        if not url.startswith(('http://', 'https://')):
            url = 'http://' + url

        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses

        soup = BeautifulSoup(response.text, 'html.parser')
        links = [a['href'] for a in soup.find_all('a', href=True)]
        return links
    except requests.exceptions.RequestException as e:
        print(f"Error fetching links from {url}: {e}")
        return []

def extract_article(link):
    try:
        # Send a GET request to the provided link
        response = requests.get(link)
        response.raise_for_status()  # Raise an exception for bad requests

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the article title
        title = soup.title.text.strip()

        # Extract the article text
        article_text = ""
        paragraphs = soup.find_all('p')  # Adjust the tag based on the structure of the webpage
        for paragraph in paragraphs:
            article_text += paragraph.text + "\n"

        return title, article_text

    except Exception as e:
        print(f"Error: {e}")
        return None, None

def scrape_and_store_data(excel_file_path):
    # Read the Excel file into a pandas DataFrame
    df = pd.read_excel(excel_file_path)

    # Assuming your Excel file has a column named 'website_url' containing the URLs
    for index, row in df.iterrows():
        website_url = row['URL']
        url_id = row['URL_ID']

        # Extract links from the website
        links = extract_links(website_url)

        # Create a text file for each URL_ID
        with open(f"Data.txt", 'w', encoding='utf-8') as file:
            # Write the article title and text to the text file
            for link in links:
                title, text = extract_article(link)
                if title and text:
                    file.write(f"Title: {title}\n")
                    file.write("\nArticle Text:\n")
                    file.write(text + "\n\n")
                else:
                    file.write(f"Failed to extract article information from {link}.\n")

if __name__ == "__main__":
    excel_file_path = 'Input.xlsx'
    scrape_and_store_data(excel_file_path)
# Out:
# Error: 406 Client Error: Not Acceptable for url: https://blackcoffer.com/get-blackcoffer-demo/
# Error: 409 Client Error: Conflict for url: https://insights.blackcoffer.com/contact/
# Error: Invalid URL '#': No scheme supplied. Perhaps you meant https://#?
# Error: Invalid URL '#': No scheme supplied. Perhaps you meant https://#?
# Error: Invalid URL '#': No scheme supplied. Perhaps you meant https://#?
# Error: Invalid URL '#': No scheme supplied. Perhaps you meant https://#?
# Error: Invalid URL '#login-form': No scheme supplied. Perhaps you meant https://#login-form?
# Error: 406 Client Error: Not Acceptable for url: https://blackcoffer.com/get-blackcoffer-demo/
# Error: 409 Client Error: Conflict for url: https://insights.blackcoffer.com/contact/
# Error: 'NoneType' object has no attribute 'text'
# Error: 400 Client Error: Bad Request for url: https://twitter.com/Blackcoffer1
# Error: 409 Client Error: Conflict for url: https://blackcoffer.com/contact-us/
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import pandas as pd
import re

nltk.download('stopwords')
nltk.download('punkt')

# Load stopwords
stop_words = set(stopwords.words('english'))

# Function to clean and tokenize text
def clean_and_tokenize(text):
    # Remove non-alphabetic characters
    text = re.sub("[^a-zA-Z]", " ", text)

    # Tokenize the text
    tokens = word_tokenize(text.lower())

    # Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]

    return tokens

# Function to calculate sentiment and readability scores
def analyze_article(title, text):
    # Clean and tokenize text
    tokens = clean_and_tokenize(text)

    # Sentiment Analysis
    positive_words = set(pd.read_csv('StopWords/positive-words.txt', header=None)[0])
    negative_words = set(pd.read_csv('StopWords/negative-words.txt', header=None)[0])

    positive_score = sum(1 for word in tokens if word in positive_words)
    negative_score = sum(1 for word in tokens if word in negative_words)
    
    polarity_score = (positive_score - negative_score) / ((positive_score + negative_score) + 0.000001)
    subjectivity_score = (positive_score + negative_score) / (len(tokens) + 0.000001)

    # Readability Analysis
    sentence_tokens = sent_tokenize(text)
    total_words = len(tokens)
    total_sentences = len(sentence_tokens)

    average_sentence_length = total_words / total_sentences

    complex_words = [word for word in tokens if len(word) > 2]
    percentage_complex_words = len(complex_words) / total_words

    fog_index = 0.4 * (average_sentence_length + percentage_complex_words)

    # Average Number of Words Per Sentence
    average_words_per_sentence = total_words / total_sentences

    # Complex Word Count
    complex_word_count = len(complex_words)

    # Word Count
    word_count = total_words

    # Personal Pronouns
    personal_pronouns = sum(1 for word in tokens if word.lower() in ["i", "we", "my", "ours", "us"])

    # Average Word Length
    average_word_length = sum(len(word) for word in tokens) / total_words

    # Create a DataFrame for the report
    report_df = pd.DataFrame({
        'Title': [title],
        'Polarity Score': [polarity_score],
        'Subjectivity Score': [subjectivity_score],
        'Average Sentence Length': [average_sentence_length],
        'Percentage of Complex Words': [percentage_complex_words],
        'Fog Index': [fog_index],
        'Average Words Per Sentence': [average_words_per_sentence],
        'Complex Word Count': [complex_word_count],
        'Word Count': [word_count],
        'Personal Pronouns Count': [personal_pronouns],
        'Average Word Length': [average_word_length]
    })

    return report_df

# Function to read the data from the text file and analyze each article
def read_and_analyze_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Split the content into articles (assuming each article starts with 'Title:')
    articles = re.split(r'Title:', content)[1:]

    # Create an empty DataFrame to store the reports
    final_report_df = pd.DataFrame()

    for article in articles:
        # Split the article into title and text
        title, text = article.split('\n', 1)
        
        # Analyze the article and append the report to the final DataFrame
        report_df = analyze_article(title.strip(), text.strip())
        final_report_df = pd.concat([final_report_df, report_df], ignore_index=True)

    return final_report_df

# Call the function to read and analyze the data
file_path = 'Data.txt'
final_report = read_and_analyze_data(file_path)

# Display the final report
print(final_report)

# Save the report to an Excel file
final_report.to_excel('Output Data Structure.xlsx', index=False)
